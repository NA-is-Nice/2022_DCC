# %%
from tqdm import tqdm
from PIL import Image,ImageFilter

# %%
path=['L2_10', 'L2_12', 'L2_15', 'L2_20', 'L2_21', 'L2_24', 'L2_25', 'L2_27', 'L2_3', 'L2_30', 'L2_33', 'L2_34', 'L2_39', 'L2_40', 'L2_41', 'L2_44', 'L2_45', 'L2_46', 'L2_50', 'L2_52']

# %%
# 모든 jpg 파일의 크기를 RGB인 3차원으로 맞춰주고 그림 크기를 256*256으로 맞춰줌
# 파일 안에 있는 사진 이름 변경

for i in range(len(path)):
    img_paths=glob.glob(f'./dataset/{path[i]}/*.jpg')
    for j in tqdm(range(len(img_paths))):
        original=Image.open(img_paths[j])
        original=original.convert('RGB')
        original=original.resize((256,256))
        original.save(f'./new_dataset/{path[i]}/{path[i]}_{j}.jpg')
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 299/299 [00:12<00:00, 24.89it/s]

# %%
# 모든 png 파일의 크기를 RGB인 3차원으로 맞춰주고 그림 크기를 256*256으로 맞춰줌
# 파일 안에 있는 사진 이름 변경

for i in range(len(path)):
    img_paths=glob.glob(f'./dataset/{path[i]}/*.png')
    img_paths1=glob.glob(f'./new_dataset/{path[i]}/*.jpg')
    for j in tqdm(range(len(img_paths))):
        original=Image.open(img_paths[j])
        original=original.convert('RGB')
        original=original.resize((256,256))
        original.save(f'./new_dataset/{path[i]}/{path[i]}_{j+len(img_paths1)}.jpg')
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████| 83/83 [00:01<00:00, 57.14it/s]
